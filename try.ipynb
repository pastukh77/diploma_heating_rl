# %%
import requests
from secret import WEATHER_KEY

d = result.json()

# %%
import requests
from util import get_temp

get_temp(date_temp="2023-04-01")

# url = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={date_temp}&end_date={date_temp}&hourly=temperature_2m"
# response = requests.get(url)

# # time_temp_dict = dict(map(response.json()['hourly']))
# time_temp_dict = dict(zip(response.json()['hourly']['time'], response.json()['hourly']['temperature_2m']))
# Out:
# {'2023-04-01 00:00:00+00:00': 6.8,
#  '2023-04-01 01:00:00+00:00': 7.1,
#  '2023-04-01 02:00:00+00:00': 7.2,
#  '2023-04-01 03:00:00+00:00': 7.2,
#  '2023-04-01 04:00:00+00:00': 7.3,
#  '2023-04-01 05:00:00+00:00': 7.3,
#  '2023-04-01 06:00:00+00:00': 7.5,
#  '2023-04-01 07:00:00+00:00': 8.5,
#  '2023-04-01 08:00:00+00:00': 10.2,
#  '2023-04-01 09:00:00+00:00': 11.3,
#  '2023-04-01 10:00:00+00:00': 12.5,
#  '2023-04-01 11:00:00+00:00': 13.2,
#  '2023-04-01 12:00:00+00:00': 13.5,
#  '2023-04-01 13:00:00+00:00': 13.6,
#  '2023-04-01 14:00:00+00:00': 12.9,
#  '2023-04-01 15:00:00+00:00': 12.3,
#  '2023-04-01 16:00:00+00:00': 11.1,
#  '2023-04-01 17:00:00+00:00': 9.6,
#  '2023-04-01 18:00:00+00:00': 8.4,
#  '2023-04-01 19:00:00+00:00': 7.7,
#  '2023-04-01 20:00:00+00:00': 7.2,
#  '2023-04-01 21:00:00+00:00': 6.7,
#  '2023-04-01 22:00:00+00:00': 6.2,
#  '2023-04-01 23:00:00+00:00': 5.8}

# %%
time_temp_dict = dict(map(lambda key: (key.replace("T", " ")  + ":00+00:00", time_temp_dict[key]), time_temp_dict))
time_temp_dict
# Out:
# {'2023-04-01 00:00:00+00:00': 6.8,
#  '2023-04-01 01:00:00+00:00': 7.1,
#  '2023-04-01 02:00:00+00:00': 7.2,
#  '2023-04-01 03:00:00+00:00': 7.2,
#  '2023-04-01 04:00:00+00:00': 7.3,
#  '2023-04-01 05:00:00+00:00': 7.3,
#  '2023-04-01 06:00:00+00:00': 7.5,
#  '2023-04-01 07:00:00+00:00': 8.5,
#  '2023-04-01 08:00:00+00:00': 10.2,
#  '2023-04-01 09:00:00+00:00': 11.3,
#  '2023-04-01 10:00:00+00:00': 12.5,
#  '2023-04-01 11:00:00+00:00': 13.2,
#  '2023-04-01 12:00:00+00:00': 13.5,
#  '2023-04-01 13:00:00+00:00': 13.6,
#  '2023-04-01 14:00:00+00:00': 12.9,
#  '2023-04-01 15:00:00+00:00': 12.3,
#  '2023-04-01 16:00:00+00:00': 11.1,
#  '2023-04-01 17:00:00+00:00': 9.6,
#  '2023-04-01 18:00:00+00:00': 8.4,
#  '2023-04-01 19:00:00+00:00': 7.7,
#  '2023-04-01 20:00:00+00:00': 7.2,
#  '2023-04-01 21:00:00+00:00': 6.7,
#  '2023-04-01 22:00:00+00:00': 6.2,
#  '2023-04-01 23:00:00+00:00': 5.8}

# %%
response.json()['hourly']
# Out:
# {'time': ['2023-04-01T00:00',
#   '2023-04-01T01:00',
#   '2023-04-01T02:00',
#   '2023-04-01T03:00',
#   '2023-04-01T04:00',
#   '2023-04-01T05:00',
#   '2023-04-01T06:00',
#   '2023-04-01T07:00',
#   '2023-04-01T08:00',
#   '2023-04-01T09:00',
#   '2023-04-01T10:00',
#   '2023-04-01T11:00',
#   '2023-04-01T12:00',
#   '2023-04-01T13:00',
#   '2023-04-01T14:00',
#   '2023-04-01T15:00',
#   '2023-04-01T16:00',
#   '2023-04-01T17:00',
#   '2023-04-01T18:00',
#   '2023-04-01T19:00',
#   '2023-04-01T20:00',
#   '2023-04-01T21:00',
#   '2023-04-01T22:00',
#   '2023-04-01T23:00'],
#  'temperature_2m': [6.8,
#   7.1,
#   7.2,
#   7.2,
#   7.3,
#   7.3,
#   7.5,
#   8.5,
#   10.2,
#   11.3,
#   12.5,
#   13.2,
#   13.5,
#   13.6,
#   12.9,
#   12.3,
#   11.1,
#   9.6,
#   8.4,
#   7.7,
#   7.2,
#   6.7,
#   6.2,
#   5.8]}

# %%
d["hourly"]
# Out:
# {'data': [{'date': '2023-04-20T11:00:00',
#    'weather': 'mostly_cloudy',
#    'icon': 5,
#    'summary': 'Mostly cloudy',
#    'temperature': 12.8,
#    'wind': {'speed': 3.2, 'dir': 'NE', 'angle': 35},
#    'cloud_cover': {'total': 68},
#    'precipitation': {'total': 0.0, 'type': 'none'}},
#   {'date': '2023-04-20T12:00:00',
#    'weather': 'partly_sunny',
#    'icon': 4,
#    'summary': 'Partly sunny',
#    'temperature': 13.2,
#    'wind': {'speed': 3.9, 'dir': 'NE', 'angle': 43},
#    'cloud_cover': {'total': 48},
#    'precipitation': {'total': 0.0, 'type': 'none'}},
#   {'date': '2023-04-20T13:00:00',
#    'weather': 'partly_sunny',
#    'icon': 4,
#    'summary': 'Partly sunny',
#    'temperature': 13.8,
#    'wind': {'speed': 4.6, 'dir': 'NE', 'angle': 41},
#    'cloud_cover': {'total': 59},
#    'precipitation': {'total': 0.0, 'type': 'none'}},
#   {'date': '2023-04-20T14:00:00',
#    'weather': 'overcast',
#    'icon': 7,
#    'summary': 'Overcast',
# ...

# %%
from data.data import get_all_rooms
df = get_all_rooms("data-bms")
df = df.set_index(["room_id", "time"])
df
# Out:
#                              valve  temp_act  temp_target  presence  temp  \
# room_id time
# 52      2022-12-23 14:00:00   20.0      22.9         23.0      30.0   7.4
# 522     2022-12-23 14:00:00   20.0      20.1         23.0      30.0   7.4
# 524     2022-12-23 14:00:00   20.0      21.0         21.0       0.0   7.4
# 52      2022-12-23 15:00:00   20.0      22.7         23.0      30.0   7.1
# 522     2022-12-23 15:00:00   20.0      20.2         23.0      30.0   7.1
# ...                            ...       ...          ...       ...   ...
# 520     2023-01-03 19:00:00   18.0      21.3         21.0       0.0   6.5
# 52      2023-01-03 20:00:00   18.0      22.2         21.0       0.0   6.4
# 522     2023-01-03 20:00:00   20.0      20.7         21.0       0.0   6.4
# 524     2023-01-03 20:00:00   18.0      21.1         21.0       0.0   6.4
# 520     2023-01-03 20:00:00   20.0      21.0         21.0       0.0   6.4
#
# ...

# %%
p1 = df[df.valve == 20]
p1["diff"] = p1.temp_target - p1.temp_act
p1["diff"].mean()
# Out:
# /var/folders/fz/vff1xm2n6d3_nqh_0k228r9h0000gp/T/ipykernel_6083/4078926091.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1["diff"] = p1.temp_target - p1.temp_act
# 0.8614305750350632

# %%
p2 = df[df.valve == 18]
p2["diff"] = p2.temp_target - p2.temp_act
p2["diff"].mean()
# Out:
# /var/folders/fz/vff1xm2n6d3_nqh_0k228r9h0000gp/T/ipykernel_6083/1662017350.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2["diff"] = p2.temp_target - p2.temp_act
# -0.439449541284404

# %%
p3 = df[df.valve == 17]
p3["diff"] = p3.temp_target - p3.temp_act
p3["diff"].mean()
# Out:
# /var/folders/fz/vff1xm2n6d3_nqh_0k228r9h0000gp/T/ipykernel_6083/777552218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p3["diff"] = p3.temp_target - p3.temp_act
# -0.5164473684210528

# %%
import pandas as pd

def nextHour(current):
  return pd.date_range(start=current, periods=2, freq="H")[1]

# %%
valve_effectiveness(20, 21)
# Out:
#                      time  valve  temp_act  temp_target  presence room_id  \
# 2     2022-12-23 14:00:00   20.0      21.0         21.0       0.0     524
# 9     2022-12-23 16:00:00   20.0      21.3         23.0      30.0     524
# 10    2022-12-23 16:00:00   20.0      20.7         21.0       0.0     520
# 13    2022-12-23 17:00:00   20.0      21.4         23.0       6.0     524
# 14    2022-12-23 17:00:00   20.0      20.5         21.0       0.0     520
# ...                   ...    ...       ...          ...       ...     ...
# 1072  2023-01-03 18:00:00   20.0      20.6         21.0       0.0     522
# 1076  2023-01-03 19:00:00   20.0      21.0         21.0       0.0     522
# 1077  2023-01-03 19:00:00   20.0      20.9         21.0       0.0     524
# 1080  2023-01-03 20:00:00   20.0      20.7         21.0       0.0     522
# 1082  2023-01-03 20:00:00   20.0      21.0         21.0       0.0     520
#
#       temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  tsun  coco
# ...

# %%
from data_process import get_all_rooms
get_all_rooms("data-bms")
# Out:
#                      time  valve  temp_act  temp_target  presence room_id  \
# 0     2022-12-23 14:00:00   20.0      22.9         23.0      30.0      52
# 1     2022-12-23 14:00:00   20.0      20.1         23.0      30.0     522
# 2     2022-12-23 14:00:00   20.0      21.0         21.0       0.0     524
# 3     2022-12-23 15:00:00   20.0      22.7         23.0      30.0      52
# 4     2022-12-23 15:00:00   20.0      20.2         23.0      30.0     522
# ...                   ...    ...       ...          ...       ...     ...
# 1078  2023-01-03 19:00:00   18.0      21.3         21.0       0.0     520
# 1079  2023-01-03 20:00:00   18.0      22.2         21.0       0.0      52
# 1080  2023-01-03 20:00:00   20.0      20.7         21.0       0.0     522
# 1081  2023-01-03 20:00:00   18.0      21.1         21.0       0.0     524
# 1082  2023-01-03 20:00:00   20.0      21.0         21.0       0.0     520
#
#       temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  tsun  coco
# ...
